# %%
# %pip install anthropic python-dotenv
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
load_dotenv()

# %%
from anthropic import Anthropic, HUMAN_PROMPT, AI_PROMPT
client = Anthropic()
model = "claude-sonnet-4-0"

# %%
message = client.messages.create(
    model=model,
    max_tokens=1000,
    messages=[
        {
            "role": "user",
            "content": "What is quantum computing? Answer in one sentence."
        }
    ]
)

message = client.messages.create(
    model=model,
    max_tokens=1000,
    messages=[
        {
            "role": "user",
            "content": "WWrite another sentence."
        }
    ]
)
message.content[0].text
# Out:
# 'The golden leaves danced gently in the autumn breeze.'

# %%
message.content[0].text
# Out:
# 'The golden leaves danced gently in the autumn breeze.'

# %%
def add_user_message(messages, text):
    messages.append({
        "role": "user",
        "content": text
    })

def add_asssitant_message(messages, text):
    messages.append({
        "role": "assistant",
        "content": text
    })  

def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages
    )
    return message.content[0].text

# %%
messages = []
add_user_message(messages, "What is quantum computing? Answer in one sentence.")
answer = chat(messages)
add_asssitant_message(messages, answer)
add_user_message(messages, "Write another sentence.")
answer = chat(messages)
answer
# Out:
# 'Quantum computers manipulate quantum bits (qubits) that can exist in multiple states simultaneously, unlike classical bits that are either 0 or 1, enabling them to perform many calculations in parallel.'

# %%
while True:
    user_input = input("User: ")
    add_user_message(messages, user_input)
    answer = chat(messages)
    add_asssitant_message(messages, answer)
    print(f"Assistant: {answer}")
# Out:
# Assistant: Quantum computers leverage qubits that can exist in multiple states simultaneously, unlike classical bits that are either 0 or 1.
#
# 1+1 = 2
# Assistant: 2 + 3 = 5
